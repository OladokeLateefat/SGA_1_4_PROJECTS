# %% [markdown]
# ### OLADOKE FUNMILOLA LATEEFAT

# %% [markdown]
# ### DATA WRANGLING

# %%
# Import libraries

import sqlite3
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
# Create a database

conn = sqlite3.connect("attr_data.db")

print("Database successfully connected")
# Out:
# Database successfully connected

# %%
# Connect to database

cursor =conn.cursor()

# check that cursor is created successfully
print("cursor created successfully\n", type(cursor))
# Out:
# cursor created successfully
#  <class 'sqlite3.Cursor'>

# %%
# checking the table in the database

sql = """
SELECT name
FROM sqlite_schema
WHERE type = "table";
"""
# execute query
cursor.execute(sql)

# output the query
result = cursor.fetchall()
result
# Out:
# [('attrition_records',), ('sqlite_sequence',)]

# %%
# 1ST STEP: GATHERING DATA
# output the query into pandas

sql = """
SELECT *
FROM attrition_records
"""
# execute query
cursor.execute(sql)

# output the query
df = pd.read_sql(sql, conn)
df.head(10)
# Out:
#    id  Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   1   41       Yes      Travel_Rarely       1102                   Sales
# 1   2   49        No  Travel_Frequently        279  Research & Development
# 2   3   37       Yes      Travel_Rarely       1373  Research & Development
# 3   4   33        No  Travel_Frequently       1392  Research & Development
# 4   5   27        No      Travel_Rarely        591  Research & Development
# 5   6   32        No  Travel_Frequently       1005  Research & Development
# 6   7   59        No      Travel_Rarely       1324  Research & Development
# 7   8   30        No      Travel_Rarely       1358  Research & Development
# 8   9   38        No  Travel_Frequently        216  Research & Development
# 9  10   36        No      Travel_Rarely       1299  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  ...  \
# 0                 1          2  Life Sciences              1  ...
# 1                 8          1  Life Sciences              1  ...
# 2                 2          2          Other              1  ...
# 3                 3          4  Life Sciences              1  ...
# 4                 2          1        Medical              1  ...
# 5                 2          2  Life Sciences              1  ...
# 6                 3          3        Medical              1  ...
# 7                24          1  Life Sciences              1  ...
# 8                23          3  Life Sciences              1  ...
# 9                27          3        Medical              1  ...
#
#    RelationshipSatisfaction  StandardHours StockOptionLevel  \
# 0                         1             80                0
# 1                         4             80                1
# 2                         2             80                0
# 3                         3             80                0
# 4                         4             80                1
# 5                         3             80                0
# 6                         1             80                3
# 7                         2             80                1
# 8                         2             80                0
# 9                         2             80                2
#
#    TotalWorkingYears  TrainingTimesLastYear  WorkLifeBalance YearsAtCompany  \
# 0                  8                      0                1              6
# 1                 10                      3                3             10
# 2                  7                      3                3              0
# 3                  8                      3                3              8
# 4                  6                      3                3              2
# 5                  8                      2                2              7
# 6                 12                      3                2              1
# 7                  1                      2                3              1
# 8                 10                      2                3              9
# 9                 17                      3                2              7
#
#    YearsInCurrentRole YearsSinceLastPromotion  YearsWithCurrManager
# 0                   4                       0                     5
# 1                   7                       1                     7
# 2                   0                       0                     0
# 3                   7                       3                     0
# 4                   2                       2                     2
# 5                   7                       3                     6
# 6                   0                       0                     0
# 7                   0                       0                     0
# 8                   7                       1                     8
# 9                   7                       7                     7
#
# [10 rows x 36 columns]

# %% [markdown]
# ### # 2ND STEP: ASSESSING DATASETS

# %%
print(df.shape)
print(df.isna().sum())
print(df.info())
print(df.duplicated().sum())
df.describe()
# Out:
# (1470, 36)
# id                          0
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# YearsAtCompany              0
# YearsInCurrentRole          0
# YearsSinceLastPromotion     0
# YearsWithCurrManager        0
# dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 36 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   id                        1470 non-null   int64
#  1   Age                       1470 non-null   int64
#  2   Attrition                 1470 non-null   object
#  3   BusinessTravel            1470 non-null   object
#  4   DailyRate                 1470 non-null   int64
#  5   Department                1470 non-null   object
#  6   DistanceFromHome          1470 non-null   int64
#  7   Education                 1470 non-null   int64
#  8   EducationField            1470 non-null   object
#  9   EmployeeCount             1470 non-null   int64
#  10  EmployeeNumber            1470 non-null   int64
#  11  EnvironmentSatisfaction   1470 non-null   int64
#  12  Gender                    1470 non-null   object
#  13  HourlyRate                1470 non-null   int64
#  14  JobInvolvement            1470 non-null   int64
#  15  JobLevel                  1470 non-null   int64
#  16  JobRole                   1470 non-null   object
#  17  JobSatisfaction           1470 non-null   int64
#  18  MaritalStatus             1470 non-null   object
#  19  MonthlyIncome             1470 non-null   int64
#  20  MonthlyRate               1470 non-null   int64
#  21  NumCompaniesWorked        1470 non-null   int64
#  22  Over18                    1470 non-null   object
#  23  OverTime                  1470 non-null   object
#  24  PercentSalaryHike         1470 non-null   int64
#  25  PerformanceRating         1470 non-null   int64
#  26  RelationshipSatisfaction  1470 non-null   int64
#  27  StandardHours             1470 non-null   int64
#  28  StockOptionLevel          1470 non-null   int64
#  29  TotalWorkingYears         1470 non-null   int64
#  30  TrainingTimesLastYear     1470 non-null   int64
#  31  WorkLifeBalance           1470 non-null   int64
#  32  YearsAtCompany            1470 non-null   int64
#  33  YearsInCurrentRole        1470 non-null   int64
#  34  YearsSinceLastPromotion   1470 non-null   int64
#  35  YearsWithCurrManager      1470 non-null   int64
# dtypes: int64(27), object(9)
# memory usage: 413.6+ KB
# None
# 0
#                 id          Age    DailyRate  DistanceFromHome    Education  \
# count  1470.000000  1470.000000  1470.000000       1470.000000  1470.000000
# mean    735.500000    36.923810   802.485714          9.192517     2.912925
# std     424.496761     9.135373   403.509100          8.106864     1.024165
# min       1.000000    18.000000   102.000000          1.000000     1.000000
# 25%     368.250000    30.000000   465.000000          2.000000     2.000000
# 50%     735.500000    36.000000   802.000000          7.000000     3.000000
# 75%    1102.750000    43.000000  1157.000000         14.000000     4.000000
# max    1470.000000    60.000000  1499.000000         29.000000     5.000000
#
#        EmployeeCount  EmployeeNumber  EnvironmentSatisfaction   HourlyRate  \
# count         1470.0     1470.000000              1470.000000  1470.000000
# mean             1.0     1024.865306                 2.721769    65.891156
# std              0.0      602.024335                 1.093082    20.329428
# min              1.0        1.000000                 1.000000    30.000000
# 25%              1.0      491.250000                 2.000000    48.000000
# 50%              1.0     1020.500000                 3.000000    66.000000
# 75%              1.0     1555.750000                 4.000000    83.750000
# max              1.0     2068.000000                 4.000000   100.000000
#
#        JobInvolvement  ...  RelationshipSatisfaction  StandardHours  \
# count     1470.000000  ...               1470.000000         1470.0
# mean         2.729932  ...                  2.712245           80.0
# std          0.711561  ...                  1.081209            0.0
# min          1.000000  ...                  1.000000           80.0
# 25%          2.000000  ...                  2.000000           80.0
# 50%          3.000000  ...                  3.000000           80.0
# 75%          3.000000  ...                  4.000000           80.0
# max          4.000000  ...                  4.000000           80.0
#
#        StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# count       1470.000000        1470.000000            1470.000000
# mean           0.793878          11.279592               2.799320
# std            0.852077           7.780782               1.289271
# min            0.000000           0.000000               0.000000
# 25%            0.000000           6.000000               2.000000
# 50%            1.000000          10.000000               3.000000
# 75%            1.000000          15.000000               3.000000
# max            3.000000          40.000000               6.000000
#
#        WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# count      1470.000000     1470.000000         1470.000000
# mean          2.761224        7.008163            4.229252
# std           0.706476        6.126525            3.623137
# min           1.000000        0.000000            0.000000
# 25%           2.000000        3.000000            2.000000
# 50%           3.000000        5.000000            3.000000
# 75%           3.000000        9.000000            7.000000
# max           4.000000       40.000000           18.000000
#
#        YearsSinceLastPromotion  YearsWithCurrManager
# count              1470.000000           1470.000000
# mean                  2.187755              4.123129
# std                   3.222430              3.568136
# min                   0.000000              0.000000
# 25%                   0.000000              2.000000
# 50%                   1.000000              3.000000
# 75%                   3.000000              7.000000
# max                  15.000000             17.000000
#
# [8 rows x 27 columns]

# %% [markdown]
# ### # 3RD STEP: CLEANING THE DATASET

# %%
#i) Changing column names to lower case 

df.rename(columns=lambda x: x.lower(), inplace=True)

# Confirm changes
df.head()
# Out:
#    id  age attrition     businesstravel  dailyrate              department  \
# 0   1   41       Yes      Travel_Rarely       1102                   Sales
# 1   2   49        No  Travel_Frequently        279  Research & Development
# 2   3   37       Yes      Travel_Rarely       1373  Research & Development
# 3   4   33        No  Travel_Frequently       1392  Research & Development
# 4   5   27        No      Travel_Rarely        591  Research & Development
#
#    distancefromhome  education educationfield  employeecount  ...  \
# 0                 1          2  Life Sciences              1  ...
# 1                 8          1  Life Sciences              1  ...
# 2                 2          2          Other              1  ...
# 3                 3          4  Life Sciences              1  ...
# 4                 2          1        Medical              1  ...
#
#    relationshipsatisfaction  standardhours stockoptionlevel  \
# 0                         1             80                0
# 1                         4             80                1
# 2                         2             80                0
# 3                         3             80                0
# 4                         4             80                1
#
#    totalworkingyears  trainingtimeslastyear  worklifebalance yearsatcompany  \
# 0                  8                      0                1              6
# 1                 10                      3                3             10
# 2                  7                      3                3              0
# 3                  8                      3                3              8
# 4                  6                      3                3              2
#
#    yearsincurrentrole yearssincelastpromotion  yearswithcurrmanager
# 0                   4                       0                     5
# 1                   7                       1                     7
# 2                   0                       0                     0
# 3                   7                       3                     0
# 4                   2                       2                     2
#
# [5 rows x 36 columns]

# %%
#ii) Change the columns headers from "paschal case" to "snake case"

df.rename(columns={'id':'id', 'age':'age', 'attrition':'attrition', 'businesstravel':'business_travel', 'dailyrate':'daily_rate', 'department':'department', 'distancefromhome':'distance_from_home', 'education':'education', 'educationfield':'education_field', 'employeecount':'employee_count', 'employeenumber':'employee_number','environmentsatisfaction':'environment_satisfaction', 'gender':'gender', 'hourlyrate':'hourly_rate', 'jobinvolvement':'job_involvement', 'joblevel':'job_level', 'jobrole':'job_role', 'jobsatisfaction':'job_satisfaction', 'maritalstatus':'marital_status', 'monthlyincome':'monthly_income', 'monthlyrate':'monthly_rate', 'numcompaniesworked':'num_companies_worked','over18':'over_18', 'overtime':'over_time', 'percentsalaryhike':'percent_salary_hike', 'performancerating':'performance_rating', 'relationshipsatisfaction':'relationship_satisfaction', 'standardhours':'standard_hours', 'stockoptionlevel':'stock_option_level', 'totalworkingyears':'total_working_years', 'trainingtimeslastyear':'training_times_last_year', 'worklifebalance':'work_life_balance', 'yearsatcompany':'years_at_company','yearsincurrentrole':'years_in_current_role', 'yearssincelastpromotion':'years_since_last_promotion', 'yearswithcurrmanager':'years_with_curr_manager'}, inplace=True)


# View the changes
df.head()
# Out:
#    id  age attrition    business_travel  daily_rate              department  \
# 0   1   41       Yes      Travel_Rarely        1102                   Sales
# 1   2   49        No  Travel_Frequently         279  Research & Development
# 2   3   37       Yes      Travel_Rarely        1373  Research & Development
# 3   4   33        No  Travel_Frequently        1392  Research & Development
# 4   5   27        No      Travel_Rarely         591  Research & Development
#
#    distance_from_home  education education_field  employee_count  ...  \
# 0                   1          2   Life Sciences               1  ...
# 1                   8          1   Life Sciences               1  ...
# 2                   2          2           Other               1  ...
# 3                   3          4   Life Sciences               1  ...
# 4                   2          1         Medical               1  ...
#
#    relationship_satisfaction  standard_hours stock_option_level  \
# 0                          1              80                  0
# 1                          4              80                  1
# 2                          2              80                  0
# 3                          3              80                  0
# 4                          4              80                  1
#
#    total_working_years  training_times_last_year  work_life_balance  \
# 0                    8                         0                  1
# 1                   10                         3                  3
# 2                    7                         3                  3
# 3                    8                         3                  3
# 4                    6                         3                  3
#
#   years_at_company  years_in_current_role years_since_last_promotion  \
# 0                6                      4                          0
# 1               10                      7                          1
# 2                0                      0                          0
# 3                8                      7                          3
# 4                2                      2                          2
#
#    years_with_curr_manager
# 0                        5
# 1                        7
# 2                        0
# 3                        0
# 4                        2
#
# [5 rows x 36 columns]

# %%
#iii) Changing attrition_column from categorical to numerical variable 

df["attrition"].replace(["Yes", "No"],[1,2], inplace = True)


# View the changes
df.head()
# Out:
#    id  age  attrition    business_travel  daily_rate              department  \
# 0   1   41          1      Travel_Rarely        1102                   Sales
# 1   2   49          2  Travel_Frequently         279  Research & Development
# 2   3   37          1      Travel_Rarely        1373  Research & Development
# 3   4   33          2  Travel_Frequently        1392  Research & Development
# 4   5   27          2      Travel_Rarely         591  Research & Development
#
#    distance_from_home  education education_field  employee_count  ...  \
# 0                   1          2   Life Sciences               1  ...
# 1                   8          1   Life Sciences               1  ...
# 2                   2          2           Other               1  ...
# 3                   3          4   Life Sciences               1  ...
# 4                   2          1         Medical               1  ...
#
#    relationship_satisfaction  standard_hours stock_option_level  \
# 0                          1              80                  0
# 1                          4              80                  1
# 2                          2              80                  0
# 3                          3              80                  0
# 4                          4              80                  1
#
#    total_working_years  training_times_last_year  work_life_balance  \
# 0                    8                         0                  1
# 1                   10                         3                  3
# 2                    7                         3                  3
# 3                    8                         3                  3
# 4                    6                         3                  3
#
#   years_at_company  years_in_current_role years_since_last_promotion  \
# 0                6                      4                          0
# 1               10                      7                          1
# 2                0                      0                          0
# 3                8                      7                          3
# 4                2                      2                          2
#
#    years_with_curr_manager
# 0                        5
# 1                        7
# 2                        0
# 3                        0
# 4                        2
#
# [5 rows x 36 columns]

# %%
# Getting the correlation of the dataframe

df.corr()
# Out:
#                                   id       age  attrition  daily_rate  \
# id                          1.000000 -0.010349   0.010369   -0.051484
# age                        -0.010349  1.000000   0.159205    0.010661
# attrition                   0.010369  0.159205   1.000000    0.056652
# daily_rate                 -0.051484  0.010661   0.056652    1.000000
# distance_from_home          0.032928 -0.001686  -0.077924   -0.004985
# education                   0.041901  0.208034   0.031373   -0.016806
# employee_count                   NaN       NaN        NaN         NaN
# employee_number             0.999906 -0.010145   0.010577   -0.050990
# environment_satisfaction    0.017424  0.010146   0.103369    0.018355
# hourly_rate                 0.034754  0.024287   0.006846    0.023381
# job_involvement            -0.007105  0.029820   0.130016    0.046135
# job_level                  -0.018041  0.509604   0.169105    0.002966
# job_satisfaction           -0.045941 -0.004892   0.103481    0.030571
# monthly_income             -0.014377  0.497855   0.159840    0.007707
# monthly_rate                0.012355  0.028051  -0.015170   -0.032182
# num_companies_worked       -0.000689  0.299635  -0.043494    0.038153
# percent_salary_hike        -0.013369  0.003634   0.013478    0.022704
# performance_rating         -0.020675  0.001904  -0.002889    0.000473
# relationship_satisfaction  -0.069654  0.053535   0.045872    0.007846
# standard_hours                   NaN       NaN        NaN         NaN
# stock_option_level          0.062452  0.037510   0.137145    0.042143
# total_working_years        -0.014095  0.680381   0.171063    0.014515
# training_times_last_year    0.023907 -0.019621   0.059478    0.002453
# work_life_balance           0.010740 -0.021490   0.063939   -0.037848
# years_at_company           -0.011557  0.311309   0.134392   -0.034055
# years_in_current_role      -0.008853  0.212901   0.160545    0.009932
# years_since_last_promotion -0.009151  0.216513   0.033019   -0.033229
# years_with_curr_manager    -0.009432  0.202089   0.156199   -0.026363
#
#                             distance_from_home  education  employee_count  \
# id                                    0.032928   0.041901             NaN
# age                                  -0.001686   0.208034             NaN
# attrition                            -0.077924   0.031373             NaN
# daily_rate                           -0.004985  -0.016806             NaN
# distance_from_home                    1.000000   0.021042             NaN
# education                             0.021042   1.000000             NaN
# employee_count                             NaN        NaN             NaN
# employee_number                       0.032916   0.042070             NaN
# environment_satisfaction             -0.016075  -0.027128             NaN
# hourly_rate                           0.031131   0.016775             NaN
# job_involvement                       0.008783   0.042438             NaN
# job_level                             0.005303   0.101589             NaN
# job_satisfaction                     -0.003669  -0.011296             NaN
# monthly_income                       -0.017014   0.094961             NaN
# monthly_rate                          0.027473  -0.026084             NaN
# num_companies_worked                 -0.029251   0.126317             NaN
# percent_salary_hike                   0.040235  -0.011111             NaN
# performance_rating                    0.027110  -0.024539             NaN
# relationship_satisfaction             0.006557  -0.009118             NaN
# standard_hours                             NaN        NaN             NaN
# stock_option_level                    0.044872   0.018422             NaN
# total_working_years                   0.004628   0.148280             NaN
# training_times_last_year             -0.036942  -0.025100             NaN
# work_life_balance                    -0.026556   0.009819             NaN
# years_at_company                      0.009508   0.069114             NaN
# years_in_current_role                 0.018845   0.060236             NaN
# years_since_last_promotion            0.010029   0.054254             NaN
# years_with_curr_manager               0.014406   0.069065             NaN
#
#                             employee_number  environment_satisfaction  \
# id                                 0.999906                  0.017424
# age                               -0.010145                  0.010146
# attrition                          0.010577                  0.103369
# daily_rate                        -0.050990                  0.018355
# distance_from_home                 0.032916                 -0.016075
# education                          0.042070                 -0.027128
# employee_count                          NaN                       NaN
# employee_number                    1.000000                  0.017621
# environment_satisfaction           0.017621                  1.000000
# hourly_rate                        0.035179                 -0.049857
# job_involvement                   -0.006888                 -0.008278
# job_level                         -0.018519                  0.001212
# job_satisfaction                  -0.046247                 -0.006784
# monthly_income                    -0.014829                 -0.006259
# monthly_rate                       0.012648                  0.037600
# num_companies_worked              -0.001251                  0.012594
# percent_salary_hike               -0.012944                 -0.031701
# performance_rating                -0.020359                 -0.029548
# relationship_satisfaction         -0.069861                  0.007665
# standard_hours                          NaN                       NaN
# stock_option_level                 0.062227                  0.003432
# total_working_years               -0.014365                 -0.002693
# training_times_last_year           0.023603                 -0.019359
# work_life_balance                  0.010309                  0.027627
# years_at_company                  -0.011240                  0.001458
# years_in_current_role             -0.008416                  0.018007
# years_since_last_promotion        -0.009019                  0.016194
# years_with_curr_manager           -0.009197                 -0.004999
#
#                             hourly_rate  ...  relationship_satisfaction  \
# id                             0.034754  ...                  -0.069654
# age                            0.024287  ...                   0.053535
# attrition                      0.006846  ...                   0.045872
# daily_rate                     0.023381  ...                   0.007846
# distance_from_home             0.031131  ...                   0.006557
# education                      0.016775  ...                  -0.009118
# employee_count                      NaN  ...                        NaN
# employee_number                0.035179  ...                  -0.069861
# environment_satisfaction      -0.049857  ...                   0.007665
# hourly_rate                    1.000000  ...                   0.001330
# job_involvement                0.042861  ...                   0.034297
# job_level                     -0.027853  ...                   0.021642
# job_satisfaction              -0.071335  ...                  -0.012454
# monthly_income                -0.015794  ...                   0.025873
# monthly_rate                  -0.015297  ...                  -0.004085
# num_companies_worked           0.022157  ...                   0.052733
# percent_salary_hike           -0.009062  ...                  -0.040490
# performance_rating            -0.002172  ...                  -0.031351
# relationship_satisfaction      0.001330  ...                   1.000000
# standard_hours                      NaN  ...                        NaN
# stock_option_level             0.050263  ...                  -0.045952
# total_working_years           -0.002334  ...                   0.024054
# training_times_last_year      -0.008548  ...                   0.002497
# work_life_balance             -0.004607  ...                   0.019604
# years_at_company              -0.019582  ...                   0.019367
# years_in_current_role         -0.024106  ...                  -0.015123
# years_since_last_promotion    -0.026716  ...                   0.033493
# years_with_curr_manager       -0.020123  ...                  -0.000867
#
#                             standard_hours  stock_option_level  \
# id                                     NaN            0.062452
# age                                    NaN            0.037510
# attrition                              NaN            0.137145
# daily_rate                             NaN            0.042143
# distance_from_home                     NaN            0.044872
# education                              NaN            0.018422
# employee_count                         NaN                 NaN
# employee_number                        NaN            0.062227
# environment_satisfaction               NaN            0.003432
# hourly_rate                            NaN            0.050263
# job_involvement                        NaN            0.021523
# job_level                              NaN            0.013984
# job_satisfaction                       NaN            0.010690
# monthly_income                         NaN            0.005408
# monthly_rate                           NaN           -0.034323
# num_companies_worked                   NaN            0.030075
# percent_salary_hike                    NaN            0.007528
# performance_rating                     NaN            0.003506
# relationship_satisfaction              NaN           -0.045952
# standard_hours                         NaN                 NaN
# stock_option_level                     NaN            1.000000
# total_working_years                    NaN            0.010136
# training_times_last_year               NaN            0.011274
# work_life_balance                      NaN            0.004129
# years_at_company                       NaN            0.015058
# years_in_current_role                  NaN            0.050818
# years_since_last_promotion             NaN            0.014352
# years_with_curr_manager                NaN            0.024698
#
#                             total_working_years  training_times_last_year  \
# id                                    -0.014095                  0.023907
# age                                    0.680381                 -0.019621
# attrition                              0.171063                  0.059478
# daily_rate                             0.014515                  0.002453
# distance_from_home                     0.004628                 -0.036942
# education                              0.148280                 -0.025100
# employee_count                              NaN                       NaN
# employee_number                       -0.014365                  0.023603
# environment_satisfaction              -0.002693                 -0.019359
# hourly_rate                           -0.002334                 -0.008548
# job_involvement                       -0.005533                 -0.015338
# job_level                              0.782208                 -0.018191
# job_satisfaction                      -0.020185                 -0.005779
# monthly_income                         0.772893                 -0.021736
# monthly_rate                           0.026442                  0.001467
# num_companies_worked                   0.237639                 -0.066054
# percent_salary_hike                   -0.020608                 -0.005221
# performance_rating                     0.006744                 -0.015579
# relationship_satisfaction              0.024054                  0.002497
# standard_hours                              NaN                       NaN
# stock_option_level                     0.010136                  0.011274
# total_working_years                    1.000000                 -0.035662
# training_times_last_year              -0.035662                  1.000000
# work_life_balance                      0.001008                  0.028072
# years_at_company                       0.628133                  0.003569
# years_in_current_role                  0.460365                 -0.005738
# years_since_last_promotion             0.404858                 -0.002067
# years_with_curr_manager                0.459188                 -0.004096
#
#                             work_life_balance  years_at_company  \
# id                                   0.010740         -0.011557
# age                                 -0.021490          0.311309
# attrition                            0.063939          0.134392
# daily_rate                          -0.037848         -0.034055
# distance_from_home                  -0.026556          0.009508
# education                            0.009819          0.069114
# employee_count                            NaN               NaN
# employee_number                      0.010309         -0.011240
# environment_satisfaction             0.027627          0.001458
# hourly_rate                         -0.004607         -0.019582
# job_involvement                     -0.014617         -0.021355
# job_level                            0.037818          0.534739
# job_satisfaction                    -0.019459         -0.003803
# monthly_income                       0.030683          0.514285
# monthly_rate                         0.007963         -0.023655
# num_companies_worked                -0.008366         -0.118421
# percent_salary_hike                 -0.003280         -0.035991
# performance_rating                   0.002572          0.003435
# relationship_satisfaction            0.019604          0.019367
# standard_hours                            NaN               NaN
# stock_option_level                   0.004129          0.015058
# total_working_years                  0.001008          0.628133
# training_times_last_year             0.028072          0.003569
# work_life_balance                    1.000000          0.012089
# years_at_company                     0.012089          1.000000
# years_in_current_role                0.049856          0.758754
# years_since_last_promotion           0.008941          0.618409
# years_with_curr_manager              0.002759          0.769212
#
#                             years_in_current_role  years_since_last_promotion  \
# id                                      -0.008853                   -0.009151
# age                                      0.212901                    0.216513
# attrition                                0.160545                    0.033019
# daily_rate                               0.009932                   -0.033229
# distance_from_home                       0.018845                    0.010029
# education                                0.060236                    0.054254
# employee_count                                NaN                         NaN
# employee_number                         -0.008416                   -0.009019
# environment_satisfaction                 0.018007                    0.016194
# hourly_rate                             -0.024106                   -0.026716
# job_involvement                          0.008717                   -0.024184
# job_level                                0.389447                    0.353885
# job_satisfaction                        -0.002305                   -0.018214
# monthly_income                           0.363818                    0.344978
# monthly_rate                            -0.012815                    0.001567
# num_companies_worked                    -0.090754                   -0.036814
# percent_salary_hike                     -0.001520                   -0.022154
# performance_rating                       0.034986                    0.017896
# relationship_satisfaction               -0.015123                    0.033493
# standard_hours                                NaN                         NaN
# stock_option_level                       0.050818                    0.014352
# total_working_years                      0.460365                    0.404858
# training_times_last_year                -0.005738                   -0.002067
# work_life_balance                        0.049856                    0.008941
# years_at_company                         0.758754                    0.618409
# years_in_current_role                    1.000000                    0.548056
# years_since_last_promotion               0.548056                    1.000000
# years_with_curr_manager                  0.714365                    0.510224
#
#                             years_with_curr_manager
# id                                        -0.009432
# age                                        0.202089
# attrition                                  0.156199
# daily_rate                                -0.026363
# distance_from_home                         0.014406
# education                                  0.069065
# employee_count                                  NaN
# employee_number                           -0.009197
# environment_satisfaction                  -0.004999
# hourly_rate                               -0.020123
# job_involvement                            0.025976
# job_level                                  0.375281
# job_satisfaction                          -0.027656
# monthly_income                             0.344079
# monthly_rate                              -0.036746
# num_companies_worked                      -0.110319
# percent_salary_hike                       -0.011985
# performance_rating                         0.022827
# relationship_satisfaction                 -0.000867
# standard_hours                                  NaN
# stock_option_level                         0.024698
# total_working_years                        0.459188
# training_times_last_year                  -0.004096
# work_life_balance                          0.002759
# years_at_company                           0.769212
# years_in_current_role                      0.714365
# years_since_last_promotion                 0.510224
# years_with_curr_manager                    1.000000
#
# [28 rows x 28 columns]

# %%
#iv) Dropping the "employee_count" and "standard_hours" columns

df.drop(columns =["employee_count","standard_hours"], axis = 1, inplace = True)

# View the changes
df.head()
# Out:
#    id  age  attrition    business_travel  daily_rate              department  \
# 0   1   41          1      Travel_Rarely        1102                   Sales
# 1   2   49          2  Travel_Frequently         279  Research & Development
# 2   3   37          1      Travel_Rarely        1373  Research & Development
# 3   4   33          2  Travel_Frequently        1392  Research & Development
# 4   5   27          2      Travel_Rarely         591  Research & Development
#
#    distance_from_home  education education_field  employee_number  ...  \
# 0                   1          2   Life Sciences                1  ...
# 1                   8          1   Life Sciences                2  ...
# 2                   2          2           Other                4  ...
# 3                   3          4   Life Sciences                5  ...
# 4                   2          1         Medical                7  ...
#
#    performance_rating relationship_satisfaction  stock_option_level  \
# 0                   3                         1                   0
# 1                   4                         4                   1
# 2                   3                         2                   0
# 3                   3                         3                   0
# 4                   3                         4                   1
#
#    total_working_years  training_times_last_year work_life_balance  \
# 0                    8                         0                 1
# 1                   10                         3                 3
# 2                    7                         3                 3
# 3                    8                         3                 3
# 4                    6                         3                 3
#
#    years_at_company years_in_current_role  years_since_last_promotion  \
# 0                 6                     4                           0
# 1                10                     7                           1
# 2                 0                     0                           0
# 3                 8                     7                           3
# 4                 2                     2                           2
#
#    years_with_curr_manager
# 0                        5
# 1                        7
# 2                        0
# 3                        0
# 4                        2
#
# [5 rows x 34 columns]

# %%
# 4TH STEP: REASSESSING DATASETS
# checking the correlation after dropping "employee_count" and "standard_hours" columns

df.corr()
# Out:
#                                   id       age  attrition  daily_rate  \
# id                          1.000000 -0.010349   0.010369   -0.051484
# age                        -0.010349  1.000000   0.159205    0.010661
# attrition                   0.010369  0.159205   1.000000    0.056652
# daily_rate                 -0.051484  0.010661   0.056652    1.000000
# distance_from_home          0.032928 -0.001686  -0.077924   -0.004985
# education                   0.041901  0.208034   0.031373   -0.016806
# employee_number             0.999906 -0.010145   0.010577   -0.050990
# environment_satisfaction    0.017424  0.010146   0.103369    0.018355
# hourly_rate                 0.034754  0.024287   0.006846    0.023381
# job_involvement            -0.007105  0.029820   0.130016    0.046135
# job_level                  -0.018041  0.509604   0.169105    0.002966
# job_satisfaction           -0.045941 -0.004892   0.103481    0.030571
# monthly_income             -0.014377  0.497855   0.159840    0.007707
# monthly_rate                0.012355  0.028051  -0.015170   -0.032182
# num_companies_worked       -0.000689  0.299635  -0.043494    0.038153
# percent_salary_hike        -0.013369  0.003634   0.013478    0.022704
# performance_rating         -0.020675  0.001904  -0.002889    0.000473
# relationship_satisfaction  -0.069654  0.053535   0.045872    0.007846
# stock_option_level          0.062452  0.037510   0.137145    0.042143
# total_working_years        -0.014095  0.680381   0.171063    0.014515
# training_times_last_year    0.023907 -0.019621   0.059478    0.002453
# work_life_balance           0.010740 -0.021490   0.063939   -0.037848
# years_at_company           -0.011557  0.311309   0.134392   -0.034055
# years_in_current_role      -0.008853  0.212901   0.160545    0.009932
# years_since_last_promotion -0.009151  0.216513   0.033019   -0.033229
# years_with_curr_manager    -0.009432  0.202089   0.156199   -0.026363
#
#                             distance_from_home  education  employee_number  \
# id                                    0.032928   0.041901         0.999906
# age                                  -0.001686   0.208034        -0.010145
# attrition                            -0.077924   0.031373         0.010577
# daily_rate                           -0.004985  -0.016806        -0.050990
# distance_from_home                    1.000000   0.021042         0.032916
# education                             0.021042   1.000000         0.042070
# employee_number                       0.032916   0.042070         1.000000
# environment_satisfaction             -0.016075  -0.027128         0.017621
# hourly_rate                           0.031131   0.016775         0.035179
# job_involvement                       0.008783   0.042438        -0.006888
# job_level                             0.005303   0.101589        -0.018519
# job_satisfaction                     -0.003669  -0.011296        -0.046247
# monthly_income                       -0.017014   0.094961        -0.014829
# monthly_rate                          0.027473  -0.026084         0.012648
# num_companies_worked                 -0.029251   0.126317        -0.001251
# percent_salary_hike                   0.040235  -0.011111        -0.012944
# performance_rating                    0.027110  -0.024539        -0.020359
# relationship_satisfaction             0.006557  -0.009118        -0.069861
# stock_option_level                    0.044872   0.018422         0.062227
# total_working_years                   0.004628   0.148280        -0.014365
# training_times_last_year             -0.036942  -0.025100         0.023603
# work_life_balance                    -0.026556   0.009819         0.010309
# years_at_company                      0.009508   0.069114        -0.011240
# years_in_current_role                 0.018845   0.060236        -0.008416
# years_since_last_promotion            0.010029   0.054254        -0.009019
# years_with_curr_manager               0.014406   0.069065        -0.009197
#
#                             environment_satisfaction  hourly_rate  \
# id                                          0.017424     0.034754
# age                                         0.010146     0.024287
# attrition                                   0.103369     0.006846
# daily_rate                                  0.018355     0.023381
# distance_from_home                         -0.016075     0.031131
# education                                  -0.027128     0.016775
# employee_number                             0.017621     0.035179
# environment_satisfaction                    1.000000    -0.049857
# hourly_rate                                -0.049857     1.000000
# job_involvement                            -0.008278     0.042861
# job_level                                   0.001212    -0.027853
# job_satisfaction                           -0.006784    -0.071335
# monthly_income                             -0.006259    -0.015794
# monthly_rate                                0.037600    -0.015297
# num_companies_worked                        0.012594     0.022157
# percent_salary_hike                        -0.031701    -0.009062
# performance_rating                         -0.029548    -0.002172
# relationship_satisfaction                   0.007665     0.001330
# stock_option_level                          0.003432     0.050263
# total_working_years                        -0.002693    -0.002334
# training_times_last_year                   -0.019359    -0.008548
# work_life_balance                           0.027627    -0.004607
# years_at_company                            0.001458    -0.019582
# years_in_current_role                       0.018007    -0.024106
# years_since_last_promotion                  0.016194    -0.026716
# years_with_curr_manager                    -0.004999    -0.020123
#
#                             job_involvement  ...  performance_rating  \
# id                                -0.007105  ...           -0.020675
# age                                0.029820  ...            0.001904
# attrition                          0.130016  ...           -0.002889
# daily_rate                         0.046135  ...            0.000473
# distance_from_home                 0.008783  ...            0.027110
# education                          0.042438  ...           -0.024539
# employee_number                   -0.006888  ...           -0.020359
# environment_satisfaction          -0.008278  ...           -0.029548
# hourly_rate                        0.042861  ...           -0.002172
# job_involvement                    1.000000  ...           -0.029071
# job_level                         -0.012630  ...           -0.021222
# job_satisfaction                  -0.021476  ...            0.002297
# monthly_income                    -0.015271  ...           -0.017120
# monthly_rate                      -0.016322  ...           -0.009811
# num_companies_worked               0.015012  ...           -0.014095
# percent_salary_hike               -0.017205  ...            0.773550
# performance_rating                -0.029071  ...            1.000000
# relationship_satisfaction          0.034297  ...           -0.031351
# stock_option_level                 0.021523  ...            0.003506
# total_working_years               -0.005533  ...            0.006744
# training_times_last_year          -0.015338  ...           -0.015579
# work_life_balance                 -0.014617  ...            0.002572
# years_at_company                  -0.021355  ...            0.003435
# years_in_current_role              0.008717  ...            0.034986
# years_since_last_promotion        -0.024184  ...            0.017896
# years_with_curr_manager            0.025976  ...            0.022827
#
#                             relationship_satisfaction  stock_option_level  \
# id                                          -0.069654            0.062452
# age                                          0.053535            0.037510
# attrition                                    0.045872            0.137145
# daily_rate                                   0.007846            0.042143
# distance_from_home                           0.006557            0.044872
# education                                   -0.009118            0.018422
# employee_number                             -0.069861            0.062227
# environment_satisfaction                     0.007665            0.003432
# hourly_rate                                  0.001330            0.050263
# job_involvement                              0.034297            0.021523
# job_level                                    0.021642            0.013984
# job_satisfaction                            -0.012454            0.010690
# monthly_income                               0.025873            0.005408
# monthly_rate                                -0.004085           -0.034323
# num_companies_worked                         0.052733            0.030075
# percent_salary_hike                         -0.040490            0.007528
# performance_rating                          -0.031351            0.003506
# relationship_satisfaction                    1.000000           -0.045952
# stock_option_level                          -0.045952            1.000000
# total_working_years                          0.024054            0.010136
# training_times_last_year                     0.002497            0.011274
# work_life_balance                            0.019604            0.004129
# years_at_company                             0.019367            0.015058
# years_in_current_role                       -0.015123            0.050818
# years_since_last_promotion                   0.033493            0.014352
# years_with_curr_manager                     -0.000867            0.024698
#
#                             total_working_years  training_times_last_year  \
# id                                    -0.014095                  0.023907
# age                                    0.680381                 -0.019621
# attrition                              0.171063                  0.059478
# daily_rate                             0.014515                  0.002453
# distance_from_home                     0.004628                 -0.036942
# education                              0.148280                 -0.025100
# employee_number                       -0.014365                  0.023603
# environment_satisfaction              -0.002693                 -0.019359
# hourly_rate                           -0.002334                 -0.008548
# job_involvement                       -0.005533                 -0.015338
# job_level                              0.782208                 -0.018191
# job_satisfaction                      -0.020185                 -0.005779
# monthly_income                         0.772893                 -0.021736
# monthly_rate                           0.026442                  0.001467
# num_companies_worked                   0.237639                 -0.066054
# percent_salary_hike                   -0.020608                 -0.005221
# performance_rating                     0.006744                 -0.015579
# relationship_satisfaction              0.024054                  0.002497
# stock_option_level                     0.010136                  0.011274
# total_working_years                    1.000000                 -0.035662
# training_times_last_year              -0.035662                  1.000000
# work_life_balance                      0.001008                  0.028072
# years_at_company                       0.628133                  0.003569
# years_in_current_role                  0.460365                 -0.005738
# years_since_last_promotion             0.404858                 -0.002067
# years_with_curr_manager                0.459188                 -0.004096
#
#                             work_life_balance  years_at_company  \
# id                                   0.010740         -0.011557
# age                                 -0.021490          0.311309
# attrition                            0.063939          0.134392
# daily_rate                          -0.037848         -0.034055
# distance_from_home                  -0.026556          0.009508
# education                            0.009819          0.069114
# employee_number                      0.010309         -0.011240
# environment_satisfaction             0.027627          0.001458
# hourly_rate                         -0.004607         -0.019582
# job_involvement                     -0.014617         -0.021355
# job_level                            0.037818          0.534739
# job_satisfaction                    -0.019459         -0.003803
# monthly_income                       0.030683          0.514285
# monthly_rate                         0.007963         -0.023655
# num_companies_worked                -0.008366         -0.118421
# percent_salary_hike                 -0.003280         -0.035991
# performance_rating                   0.002572          0.003435
# relationship_satisfaction            0.019604          0.019367
# stock_option_level                   0.004129          0.015058
# total_working_years                  0.001008          0.628133
# training_times_last_year             0.028072          0.003569
# work_life_balance                    1.000000          0.012089
# years_at_company                     0.012089          1.000000
# years_in_current_role                0.049856          0.758754
# years_since_last_promotion           0.008941          0.618409
# years_with_curr_manager              0.002759          0.769212
#
#                             years_in_current_role  years_since_last_promotion  \
# id                                      -0.008853                   -0.009151
# age                                      0.212901                    0.216513
# attrition                                0.160545                    0.033019
# daily_rate                               0.009932                   -0.033229
# distance_from_home                       0.018845                    0.010029
# education                                0.060236                    0.054254
# employee_number                         -0.008416                   -0.009019
# environment_satisfaction                 0.018007                    0.016194
# hourly_rate                             -0.024106                   -0.026716
# job_involvement                          0.008717                   -0.024184
# job_level                                0.389447                    0.353885
# job_satisfaction                        -0.002305                   -0.018214
# monthly_income                           0.363818                    0.344978
# monthly_rate                            -0.012815                    0.001567
# num_companies_worked                    -0.090754                   -0.036814
# percent_salary_hike                     -0.001520                   -0.022154
# performance_rating                       0.034986                    0.017896
# relationship_satisfaction               -0.015123                    0.033493
# stock_option_level                       0.050818                    0.014352
# total_working_years                      0.460365                    0.404858
# training_times_last_year                -0.005738                   -0.002067
# work_life_balance                        0.049856                    0.008941
# years_at_company                         0.758754                    0.618409
# years_in_current_role                    1.000000                    0.548056
# years_since_last_promotion               0.548056                    1.000000
# years_with_curr_manager                  0.714365                    0.510224
#
#                             years_with_curr_manager
# id                                        -0.009432
# age                                        0.202089
# attrition                                  0.156199
# daily_rate                                -0.026363
# distance_from_home                         0.014406
# education                                  0.069065
# employee_number                           -0.009197
# environment_satisfaction                  -0.004999
# hourly_rate                               -0.020123
# job_involvement                            0.025976
# job_level                                  0.375281
# job_satisfaction                          -0.027656
# monthly_income                             0.344079
# monthly_rate                              -0.036746
# num_companies_worked                      -0.110319
# percent_salary_hike                       -0.011985
# performance_rating                         0.022827
# relationship_satisfaction                 -0.000867
# stock_option_level                         0.024698
# total_working_years                        0.459188
# training_times_last_year                  -0.004096
# work_life_balance                          0.002759
# years_at_company                           0.769212
# years_in_current_role                      0.714365
# years_since_last_promotion                 0.510224
# years_with_curr_manager                    1.000000
#
# [26 rows x 26 columns]

# %% [markdown]
# ### DATA VISUALIZATION

# %%
# Mulivariate Analysis: Numeric variables

plt.figure(figsize=[20,5])
sns.heatmap(df.corr(), annot = True, fmt =".3f")
plt.title("Heatmaps for Numerical variables");

# %% [markdown]
# ### QUESTION 1: WHAT DO YOU THINK ARE THE 3 FACTORS BEHIND EMPLOYEE ATTRITION?
#
# ### ANSWER: THE FACTORS ARE: TOTAL WORKING YEARS, JOB LEVEL AND YEARS IN CURRENT ROLE

# %%
inc_edu = df.groupby("education")["monthly_income"].mean()

fig, ax = plt.subplots(figsize=(8,5))
plt.bar(inc_edu.index, inc_edu, color = "g")
plt.title("Average Income by Education Per Month")
plt.xlabel("Education Level")
plt.ylabel("Average Monthly Income");

# %% [markdown]
# ### QUESTION 2: WHAT IS THE RELATIONSHIP BETWEEN EDUCATION AND MONTHLY INCOME?
#
# ### ANSWER: THERE IS A POSITIVE RELATIONSHIP BETWEEN MONTHLY INCOME AND EDUCATION; BECAUSE THE HIGHER THE EDUCATIONAL LEVEL, THE HIGHER THE AVERAGE MONTHLY INCOME

# %%
fig, ax = plt.subplots(figsize=(7, 5))
sns.boxplot(data=df, y="attrition", x="age",orient='h')
plt.title("Boxplot of Attrition vs. Age");

# %% [markdown]
# ### QUESTION 3: WHAT IS THE EFFECT OF AGE ON ATTRITION?
#
# ### ANSWER: ATTRITION IS MORE COMMON AMIDST THE YOUNGER EMPLOYEES TO THAT OF THE OLDER EMPLOYEES

# %%
# Mulivariate Analysis: Numeric variables

plt.figure(figsize=[20,7])
sns.heatmap(df.corr(), annot = True, fmt =".3f");

# %% [markdown]
# ### QUESTION4: IS INCOME THE MAIN FACTOR IN EMPLOYEE ATTRITION?
#
# ### ANSWER: ACCORDING THE HEATMAP ABOVE, INCOME IS NOT THE MAIN FACTOR; IT'S THE 4TH FACTOR

# %%
# Mulivariate Analysis: Numeric variables

plt.figure(figsize=[20,7])
sns.heatmap(df.corr(), annot = True, fmt =".3f")
plt.title("Heatmaps for Numerical variables");

# %% [markdown]
# ### QUESTION 5: HOW DOES WORK-LIFE BALANCE IMPACT THE OVERALL ATTRITION RATE?
#
# ### ANSWER: WORK-LIFE BALANCE HAS NO IMPACT ON ATTRITION RATE; BECAUSE THE CORRELATION IS 0.064 WHICH INDICATES "A WEAK POSITIVE CORRELATION"¶
